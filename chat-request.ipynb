# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /home/soham/.local/lib/python3.10/site-packages (0.97.0)
# Requirement already satisfied: python-dotenv in /home/soham/.local/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/soham/.local/lib/python3.10/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/soham/.local/lib/python3.10/site-packages (from anthropic) (2.13.3)
# Requirement already satisfied: sniffio in /home/soham/.local/lib/python3.10/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from anthropic) (1.7.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /home/soham/.local/lib/python3.10/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /home/soham/.local/lib/python3.10/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/soham/.local/lib/python3.10/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/soham/.local/lib/python3.10/site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/soham/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.3)
# Requirement already satisfied: httpcore==1.* in /home/soham/.local/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1,>=0.25.0->anthropic) (2020.6.20)
# Requirement already satisfied: h11>=0.16 in /home/soham/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /home/soham/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/soham/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/soham/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

# %%
# Create an API client 
client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )

    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

final_answer
# Out:
# 'Unlike classical bits that are either 0 or 1, qubits can exist in multiple states simultaneously, allowing quantum computers to explore many possible solutions in parallel.'
