# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate the value of pi to the 5th digit
    
    Then create a .test.py file to test your implementation
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit and test it. Let me start by examining the main.py file.
# Let me try viewing the current directory:
# Great! Now let me view the main.py file:
# Perfect! Now I'll add a function to calculate pi to the 5th digit. I'll use the Bailey–Borwein–Plouffe formula or a simpler approach with the Machin formula. Let me add the function to main.py:
# Now let me create a test.py file to test the implementation:
# Perfect! Let me verify the files were created correctly:
# Perfect! I've successfully completed your request. Here's a summary of what I created:
#
# ## Summary
#
# ### 1. **Updated main.py** with a new function:
# - **`calculate_pi_to_5th_digit()`** - Uses the Machin formula to calculate pi with high precision
#   - Formula: π = 16×arctan(1/5) - 4×arctan(1/239)
#   - Uses Python's `Decimal` module for high-precision arithmetic
#   - Implements arctan using Taylor series expansion
#   - Returns pi rounded to 5 decimal places: **3.14159**
#
# ### 2. **Created test.py** with comprehensive unit tests:
# - **test_pi_to_5th_digit()** - Verifies the result equals exactly 3.14159
# - **test_pi_is_float()** - Ensures the return type is float
# - **test_pi_is_positive()** - Confirms pi is a positive value
# - **test_pi_is_in_reasonable_range()** - Validates pi is between 3.1 and 3.2
# - **test_pi_decimal_places()** - Ensures proper rounding to 5 decimal places
#
# You can run the tests with:
# ```bash
# python test.py
# ```
#
# The implementation uses the mathematically proven Machin formula, which converges quickly and provides accurate results for calculating pi to the required precision!
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate the value of pi to the 5th digit\n    \n    Then create a .test.py file to test your implementation\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit and test it. Let me start by examining the main.py file.", type='text'),
#    ToolUseBlock(id='toolu_01LWC4Zk4nFRZk59G1WShdVB', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '/'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01LWC4Zk4nFRZk59G1WShdVB',
#     'content': "Error: Access denied: Path '/' is outside the allowed directory",
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Let me try viewing the current directory:', type='text'),
#    ToolUseBlock(id='toolu_01BBDBTV9SC4aCZd1c3AZLbL', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01BBDBTV9SC4aCZd1c3AZLbL',
#     'content': '"output.html\\nchat-request.ipynb\\ndataset-code-model.json\\n001_tools_008.ipynb\\nevaluation.json\\n002_prompting_completed.ipynb\\n003_prompting_exercise.ipynb\\n001_prompt_evals.ipynb\\n005_text_editor_tool.ipynb\\n001_prompt_evals_complete.ipynb\\nprompt-exercise-output.html\\noutput.json\\nprompt-exercise-output.json\\n001_prompting.ipynb\\nprompt-exercise.json\\n001_prompt_evals_fns.ipynb\\nfinal-eval.json\\n001_tools_007.ipynb\\n.env\\n001_tools.ipynb\\n.backups\\n001_tools_009.ipynb\\n003_tool_streaming_completed.ipynb\\n.gitignore\\ndataset.json\\nstream-request.ipynb\\nmain.py\\nrequest-exercise.ipynb"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Great! Now let me view the main.py file:', type='text'),
#    ToolUseBlock(id='toolu_01GC6gXshfkXNwsNDct7oQDp', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01GC6gXshfkXNwsNDct7oQDp',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! Now I'll add a function to calculate pi to the 5th digit. I'll use the Bailey–Borwein–Plouffe formula or a simpler approach with the Machin formula. Let me add the function to main.py:", type='text'),
#    ToolUseBlock(id='toolu_01QNnfSg6cu8zvCafh4CMmfn', caller=DirectCaller(type='direct'), input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def greeting():\n    print("Hi there")', 'new_str': 'def greeting():\n    print("Hi there")\n\n\ndef calculate_pi_to_5th_digit():\n    """\n    Calculate the value of pi to the 5th digit using the Machin formula.\n    Machin formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    Returns pi rounded to 5 decimal places: 3.14159\n    """\n    from decimal import Decimal, getcontext\n    \n    # Set precision high enough for accurate calculation\n    getcontext().prec = 50\n    \n    # Using Machin formula: pi = 16*arctan(1/5) - 4*arctan(1/239)\n    def arctan(x, num_terms=100):\n        """Calculate arctan using Taylor series"""\n        x = Decimal(x)\n        power = x\n        result = power\n        for n in range(1, num_terms):\n            power *= -x * x\n            result += power / (2 * n + 1)\n        return result\n    \n    pi = 4 * (4 * arctan(Decimal(1)/Decimal(5)) - arctan(Decimal(1)/Decimal(239)))\n    \n    # Round to 5 decimal places\n    pi_rounded = float(round(pi, 5))\n    return pi_rounded'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01QNnfSg6cu8zvCafh4CMmfn',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Now let me create a test.py file to test the implementation:', type='text'),
#    ToolUseBlock(id='toolu_01WaaV5dDA9QF1x8kjc34FxA', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': 'import unittest\nfrom main import calculate_pi_to_5th_digit\n\n\nclass TestPiCalculation(unittest.TestCase):\n    """Test cases for pi calculation function"""\n    \n    def test_pi_to_5th_digit(self):\n        """Test that pi is calculated correctly to the 5th decimal place"""\n        result = calculate_pi_to_5th_digit()\n        # Pi to 5 decimal places is 3.14159\n        expected = 3.14159\n        self.assertEqual(result, expected, \n                         f"Expected {expected}, but got {result}")\n    \n    def test_pi_is_float(self):\n        """Test that the result is a float"""\n        result = calculate_pi_to_5th_digit()\n        self.assertIsInstance(result, float, \n                              "Result should be a float")\n    \n    def test_pi_is_positive(self):\n        """Test that pi is positive"""\n        result = calculate_pi_to_5th_digit()\n        self.assertGreater(result, 0, \n                           "Pi should be positive")\n    \n    def test_pi_is_in_reasonable_range(self):\n        """Test that pi is approximately 3.14"""\n        result = calculate_pi_to_5th_digit()\n        self.assertGreater(result, 3.1, \n                           "Pi should be greater than 3.1")\n        self.assertLess(result, 3.2, \n                        "Pi should be less than 3.2")\n    \n    def test_pi_decimal_places(self):\n        """Test that result has exactly 5 decimal places"""\n        result = calculate_pi_to_5th_digit()\n        # Round to 5 decimals and ensure it\'s equal (no extra precision)\n        rounded = round(result, 5)\n        self.assertEqual(result, rounded, \n                         "Result should be rounded to 5 decimal places")\n\n\nif __name__ == \'__main__\':\n    # Run tests with verbose output\n    unittest.main(verbosity=2)\n'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01WaaV5dDA9QF1x8kjc34FxA',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! Let me verify the files were created correctly:', type='text'),
#    ToolUseBlock(id='toolu_01A1n32tSwwzBEGSjedeQ1CS', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use'),
#    ToolUseBlock(id='toolu_01ReTr1yoMRHe93EXaVhqj9u', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './test.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01A1n32tSwwzBEGSjedeQ1CS',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there\\")\\n3: \\n4: \\n5: def calculate_pi_to_5th_digit():\\n6:     \\"\\"\\"\\n7:     Calculate the value of pi to the 5th digit using the Machin formula.\\n8:     Machin formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n9:     Returns pi rounded to 5 decimal places: 3.14159\\n10:     \\"\\"\\"\\n11:     from decimal import Decimal, getcontext\\n12:     \\n13:     # Set precision high enough for accurate calculation\\n14:     getcontext().prec = 50\\n15:     \\n16:     # Using Machin formula: pi = 16*arctan(1/5) - 4*arctan(1/239)\\n17:     def arctan(x, num_terms=100):\\n18:         \\"\\"\\"Calculate arctan using Taylor series\\"\\"\\"\\n19:         x = Decimal(x)\\n20:         power = x\\n21:         result = power\\n22:         for n in range(1, num_terms):\\n23:             power *= -x * x\\n24:             result += power / (2 * n + 1)\\n25:         return result\\n26:     \\n27:     pi = 4 * (4 * arctan(Decimal(1)/Decimal(5)) - arctan(Decimal(1)/Decimal(239)))\\n28:     \\n29:     # Round to 5 decimal places\\n30:     pi_rounded = float(round(pi, 5))\\n31:     return pi_rounded"',
#     'is_error': False},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_01ReTr1yoMRHe93EXaVhqj9u',
#     'content': '"1: import unittest\\n2: from main import calculate_pi_to_5th_digit\\n3: \\n4: \\n5: class TestPiCalculation(unittest.TestCase):\\n6:     \\"\\"\\"Test cases for pi calculation function\\"\\"\\"\\n7:     \\n8:     def test_pi_to_5th_digit(self):\\n9:         \\"\\"\\"Test that pi is calculated correctly to the 5th decimal place\\"\\"\\"\\n10:         result = calculate_pi_to_5th_digit()\\n11:         # Pi to 5 decimal places is 3.14159\\n12:         expected = 3.14159\\n13:         self.assertEqual(result, expected, \\n14:                          f\\"Expected {expected}, but got {result}\\")\\n15:     \\n16:     def test_pi_is_float(self):\\n17:         \\"\\"\\"Test that the result is a float\\"\\"\\"\\n18:         result = calculate_pi_to_5th_digit()\\n19:         self.assertIsInstance(result, float, \\n20:                               \\"Result should be a float\\")\\n21:     \\n22:     def test_pi_is_positive(self):\\n23:         \\"\\"\\"Test that pi is positive\\"\\"\\"\\n24:         result = calculate_pi_to_5th_digit()\\n25:         self.assertGreater(result, 0, \\n26:                            \\"Pi should be positive\\")\\n27:     \\n28:     def test_pi_is_in_reasonable_range(self):\\n29:         \\"\\"\\"Test that pi is approximately 3.14\\"\\"\\"\\n30:         result = calculate_pi_to_5th_digit()\\n31:         self.assertGreater(result, 3.1, \\n32:                            \\"Pi should be greater than 3.1\\")\\n33:         self.assertLess(result, 3.2, \\n34:                         \\"Pi should be less than 3.2\\")\\n35:     \\n36:     def test_pi_decimal_places(self):\\n37:         \\"\\"\\"Test that result has exactly 5 decimal places\\"\\"\\"\\n38:         result = calculate_pi_to_5th_digit()\\n39:         # Round to 5 decimals and ensure it\'s equal (no extra precision)\\n40:         rounded = round(result, 5)\\n41:         self.assertEqual(result, rounded, \\n42:                          \\"Result should be rounded to 5 decimal places\\")\\n43: \\n44: \\n45: if __name__ == \'__main__\':\\n46:     # Run tests with verbose output\\n47:     unittest.main(verbosity=2)\\n48: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've successfully completed your request. Here's a summary of what I created:\n\n## Summary\n\n### 1. **Updated main.py** with a new function:\n- **`calculate_pi_to_5th_digit()`** - Uses the Machin formula to calculate pi with high precision\n  - Formula: π = 16×arctan(1/5) - 4×arctan(1/239)\n  - Uses Python's `Decimal` module for high-precision arithmetic\n  - Implements arctan using Taylor series expansion\n  - Returns pi rounded to 5 decimal places: **3.14159**\n\n### 2. **Created test.py** with comprehensive unit tests:\n- **test_pi_to_5th_digit()** - Verifies the result equals exactly 3.14159\n- **test_pi_is_float()** - Ensures the return type is float\n- **test_pi_is_positive()** - Confirms pi is a positive value\n- **test_pi_is_in_reasonable_range()** - Validates pi is between 3.1 and 3.2\n- **test_pi_decimal_places()** - Ensures proper rounding to 5 decimal places\n\nYou can run the tests with:\n```bash\npython test.py\n```\n\nThe implementation uses the mathematically proven Machin formula, which converges quickly and provides accurate results for calculating pi to the required precision!", type='text')]}]
